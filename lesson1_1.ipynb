# %%
print("Hello!python")
# Out:
# Hello!python

# %%
print(123,"我是int")
print(0.123, '我是float')
print("字串","這是str")
print(True, "我是bool值")
#這是引數值","
#使用方法"()"
# Out:
# 123 我是int
# 0.123 我是float
# 字串 這是str
# True 我是bool值

# %%
56 + 92
# Out:
# 148

# %%
56 + 92.0
# Out:
# 148.0

# %%
"eee" + "20.4"
"eee" + 20.3
#儲存格最後一行，如是運算且無任何接收會掉下顯示出來
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 "eee" + "20.4"
# ----> 2 "eee" + 20.3
#       3 #儲存格最後一行，如是運算且無任何接收會掉下顯示出來
#
# TypeError: can only concatenate str (not "float") to str

# %%
99**999
# Out:
# ...

# %%
5+8, 2-2, "111+21",7%3
# Out:
# (13, 0, '111+21', 1)
